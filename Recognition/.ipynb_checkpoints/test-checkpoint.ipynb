# %%
# !mkdir ./yolov5
# Out:
# mkdir: ./yolov5: File exists

# %%
# !cd ./yolov5
# !git clone https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5n.pt
# !git clone https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt
# !git clone https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5m.pt
# !git clone https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5l.pt
# !git clone https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt
# Out:
# 'yolov5n.pt'에 복제합니다...
# remote: Not Found
# fatal: repository 'https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5n.pt/' not found
# 'yolov5s.pt'에 복제합니다...
# remote: Not Found
# fatal: repository 'https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt/' not found
# 'yolov5m.pt'에 복제합니다...
# remote: Not Found
# fatal: repository 'https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5m.pt/' not found
# 'yolov5l.pt'에 복제합니다...
# remote: Not Found
# fatal: repository 'https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5l.pt/' not found
# 'yolov5x.pt'에 복제합니다...
# remote: Not Found
# fatal: repository 'https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt/' not found

# %%
# !pip install torchvision==0.10.0
# !pip install torch==1.9.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# ...

# %%
# !find . -name "*.DS_Store" -type f -delete

# %%
# !python3 train.py --is-add-user=True
# Out:
# Fusing layers...
# /opt/anaconda3/envs/test2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Update feature!

# %%
# !python3 recognize.py
# Out:
# Fusing layers...
# /opt/anaconda3/envs/test2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# ...

# %%
# !python3 train.py --is-add-user=True
# Out:
# Fusing layers...
# /opt/anaconda3/envs/test2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Traceback (most recent call last):
#   File "train.py", line 212, in <module>
#     main(opt)
#   File "train.py", line 208, in main
#     training(**vars(opt))
#   File "train.py", line 140, in training
#     for image_name in os.listdir(person_image_path):
# NotADirectoryError: [Errno 20] Not a directory: './database/additional-training-datasets/.DS_Store'

# %%
# !python3 recognize.py
# Out:
# Fusing layers...
# /opt/anaconda3/envs/test2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# ...

# %%
# !python3 train.py
# Out:
# Fusing layers...
# /opt/anaconda3/envs/test2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Traceback (most recent call last):
#   File "train.py", line 212, in <module>
#     main(opt)
#   File "train.py", line 208, in main
#     training(**vars(opt))
#   File "train.py", line 182, in training
#     images_emb = np.vstack((old_images_emb, images_emb))
#   File "<__array_function__ internals>", line 200, in vstack
#   File "/opt/anaconda3/envs/test2/lib/python3.8/site-packages/numpy/core/shape_base.py", line 296, in vstack
#     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
# ...

# %%
# !python3 recognize.py
# Out:
# Fusing layers...
# /opt/anaconda3/envs/test2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ^C

# %%
# !pip install -r requirements.txt

# %%
from PIL import Image
import os

# %%
raw_path = './database/full-training-datasets/kbom/' # 원본 이미지 경로
token_list = os.listdir(raw_path) # 원본 이미지 경로 내 폴더들 list
data_path = './database/face-datasets/kbom/'  # 저장할 이미지 경로

# resize 시작 --------------------
for token in token_list:
#원본 이미지 경로와 저장할 경로 이미지 지정
    image_path = raw_path
    save_path = data_path + token
    
    #원본 이미지 경로의 모든 이미지 list 지정
    data_list = os.listdir(image_path)
    
    print(len(data_list))


    # 이미지 열기
    im = Image.open(image_path + name)

    # 이미지 resize
    im = im.resize((160, 160))

    # 이미지 JPG로 저장
    im = im.convert('RGB')
    im.save(save_path)
    print('end ::: ' + token)
# Out:
# 6
# end ::: 001.jpeg
# 6
# end ::: 006.jpeg
# 6
# end ::: 005.jpeg
# 6
# end ::: 004.jpeg
# 6
# end ::: 003.jpeg
# 6
# end ::: 002.jpeg

# %%
pwd
# Out:
# '/Users/spring/Desktop/strongcom/face-recognition'
